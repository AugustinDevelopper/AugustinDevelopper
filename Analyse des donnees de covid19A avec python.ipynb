# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustinDevelopper/AugustinDevelopper/blob/main/Analyse%20des%20donnees%20de%20covid19A%20avec%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
import io
uploaded=files.upload()
# Out:
#      <input type="file" id="files-2a10e8ae-e7ee-454f-bce5-1a8325f63f52" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a10e8ae-e7ee-454f-bce5-1a8325f63f52">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel(io.BytesIO(uploaded['COVID_19.xlsx']))
df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-12-14   14     12  2020    746       6             Afghanistan
# 1     2020-12-13   13     12  2020    298       9             Afghanistan
# 2     2020-12-12   12     12  2020    113      11             Afghanistan
# 3     2020-12-11   11     12  2020     63      10             Afghanistan
# 4     2020-12-10   10     12  2020    202      16             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 61895 2020-03-25   25      3  2020      0       0                Zimbabwe
# 61896 2020-03-24   24      3  2020      0       1                Zimbabwe
# 61897 2020-03-23   23      3  2020      0       0                Zimbabwe
# 61898 2020-03-22   22      3  2020      1       0                Zimbabwe
# 61899 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
df.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-12-14   14     12  2020    746       6             Afghanistan    AF
# 1 2020-12-13   13     12  2020    298       9             Afghanistan    AF
# 2 2020-12-12   12     12  2020    113      11             Afghanistan    AF
# 3 2020-12-11   11     12  2020     63      10             Afghanistan    AF
# 4 2020-12-10   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...

# %%
df.tail()
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 61895 2020-03-25   25      3  2020      0       0                Zimbabwe
# 61896 2020-03-24   24      3  2020      0       1                Zimbabwe
# 61897 2020-03-23   23      3  2020      0       0                Zimbabwe
# 61898 2020-03-22   22      3  2020      1       0                Zimbabwe
# 61899 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 61895    ZW                  ZWE   14645473.0       Africa
# 61896    ZW                  ZWE   14645473.0       Africa
# 61897    ZW                  ZWE   14645473.0       Africa
# 61898    ZW                  ZWE   14645473.0       Africa
# 61899    ZW                  ZWE   14645473.0       Africa
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 61895                                                NaN
# ...

# %%
df.dtypes
# Out:
# dateRep                                                       datetime64[ns]
# day                                                                    int64
# month                                                                  int64
# year                                                                   int64
# cases                                                                  int64
# deaths                                                                 int64
# countriesAndTerritories                                               object
# geoId                                                                 object
# countryterritoryCode                                                  object
# popData2019                                                          float64
# continentExp                                                          object
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61900 entries, 0 to 61899
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     61900 non-null  datetime64[ns]
#  1   day                                                         61900 non-null  int64
#  2   month                                                       61900 non-null  int64
#  3   year                                                        61900 non-null  int64
#  4   cases                                                       61900 non-null  int64
#  5   deaths                                                      61900 non-null  int64
#  6   countriesAndTerritories                                     61900 non-null  object
# ...

# %%
subdf=df[['dateRep','countriesAndTerritories','cases','deaths']]
subdf
# Out:
#          dateRep countriesAndTerritories  cases  deaths
# 0     2020-12-14             Afghanistan    746       6
# 1     2020-12-13             Afghanistan    298       9
# 2     2020-12-12             Afghanistan    113      11
# 3     2020-12-11             Afghanistan     63      10
# 4     2020-12-10             Afghanistan    202      16
# ...          ...                     ...    ...     ...
# 61895 2020-03-25                Zimbabwe      0       0
# 61896 2020-03-24                Zimbabwe      0       1
# 61897 2020-03-23                Zimbabwe      0       0
# 61898 2020-03-22                Zimbabwe      1       0
# 61899 2020-03-21                Zimbabwe      1       0
#
# [61900 rows x 4 columns]

# %%
subdf['cases'].mean()
# Out:
# 1155.147237479806

# %%
subdf.describe()
# Out:
#                cases        deaths
# count   61900.000000  61900.000000
# mean     1155.147237     26.055460
# std      6779.224479    131.227055
# min     -8261.000000  -1918.000000
# 25%         0.000000      0.000000
# 50%        15.000000      0.000000
# 75%       273.000000      4.000000
# max    234633.000000   4928.000000
